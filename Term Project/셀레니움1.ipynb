# %%
from selenium import webdriver
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('C:\Selenium\chromedriver_win32\chromedriver.exe') #이거를 실행하면 빈창이뜨는데 빈창을 끄면 안돼!!

# %%
url = 'https://www.coupang.com/vp/products/6981994?itemId=457932881&vendorItemId=4136573151&sourceType=CATEGORY&categoryId=195166&isAddedCart='
driver.get(url)
# 이거 실행시 쿠팡의 내가선택해놓은 상품으로 이동하는데 역시 가상브라우저끄면안돼!

# %%
html=driver.page_source #1p리뷰
soup = BeautifulSoup(html,'lxml')
#댓글가져오기
review1 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in review1:
    print (re.text)

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[3]').click()
#2p이지클릭

# %%
#2p리뷰
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
#댓글가져오기
review2 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in review2:
    print (re.text)
# Out:
#
#                         진짜 맛있다...하나 더 살껄 후회하는 맛이에요.
# 놀이동산 츄러스 맛이라고 하는데..
# 그거랑 똑같진 않고요...
# 그 느낌은 나요. 살아있어요..
# 가족들한테 어때?-> 물으니 맛있네~ 하고
# 뭐랑 비슷하지 않아?->시나몬 맛나네
# 아니 내말은..츄러스랑은?->니말 들으니까 그런다 추러스 비슷한 맛나네..
# 한 입 먹자마자 으잉? 츄러스 맛이다!! 라고 직접적으로 떠오르기 보다는
# 츄러스맛이 날꺼야 라고 하니까 진짜 츄러스 먹는 느낌이에요
#
# 그 달달함과 시나몬향...우유까지 맛있어지고..
# 그냥 먹어도 맛있지만 그 진가는 우유를 탔을 때 느껴져요..
# 우유에 넣어서 막 먹으면 바삭하면서 우우와 함께 먹는 느낌..
# 맛의 강도는
# 오레오에 우유 찍어먹는 거랑 비슷하게 맛있어요
# 살아있길 잘했구나 하는 느낌에요.
# 미뢰가 존재하는 것에 감사함을 느끼고요
#
# 좀 시간 지나면 시리얼이 살짝 눅눅해 지면서~
# 그 달디 단 성분과 시나몬 가루같은게? 우유에 섞여 들어가요.
# 우유랑 함께 떠먹으면
# 머리 속에서 상투스가 울려퍼지는 거 같은 전율감이 들어요..
#
# 크기는 생각보다 얼마 안돼요.
# 큰 용량 기대라고 먹으면 큰일..
# 어차피 금방 먹을 꺼 같아서요.. 오늘 아침에 한그릇 하고 방금도 한그릇 했어요.
# 다이어트 해야 하는데 눈에 보이니 손이 가네요.
#
# 저희 엄마는 단거 별로 않좋아 해서 그런지 그냥 그렇대요 맛은 있는데..
# 저처럼 환장할 맛은 아니래요...
#
# 츄러스나 단거 좋아하는 분들한테는 추천입니다
#
# 제 베스트 레시피는 시리얼이랑 바나나 토핑해서 우유 넣고 살짝 있다가
# 우유에 단맛이 스며들때쯤 먹는 맛이에요!!
# 입안에서 세가지가 동시에 어울려지면서 축제를 하는거 같아요~
#
#
#
#
#                         츄러스 맛이랑 비교했을 때
# 토스트가 우유에 먹기 좋고
# 츄러스는 과자로 먹기 좋아요
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[4]').click()

# %%
#3p리뷰
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
review3 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in review3:
    print (re.text)
# Out:
#
#                         워낙에 유명한 제품이라 세일때 맞춰서
# 드디어 구매!!ㅠㅠ 일단 크런치한 시니얼들
# 완전 우유에 녹기 전 빠삭빠삭한것들 좋아하는데
# 이 시나몬 토스트는 그런 빠삭빠삭함은 아닌데
# 정말 파살파살이라고 해야하나? 식감이 너무 재밌고,
# 맛이 맛남!!ㅠㅠ 우유에 오래 담궈놓으면 조금 있다
# 바로 풀어지기 때문에 조금씩 넣어서 드시길 추천!
#
#
#
#
#                         이 시리얼은 먹어본 적 없었는데, 후기에서 맛있다고 하고 시나몬을 좋아해서 구매하였습니다. 시리얼의 크기는 엄지 손톱보다 살짝 더 크고, 맛은 달달한 시나몬 맛입니다.
# 원래 식감 자체가 부드러운 편이고 우유에 넣으면 금방 눅눅? 부드러워지는데 전 눅눅한 것도 좋아해서 정말 맛있게 먹었습니다. 우유랑 같이 안먹어도 맛있어요. 금방 다 먹을 거 같아요. 시나몬 좋아하시고 부드러운 거 좋아하시면 아주 좋아하실 거 같아요. 정말 맛있어요...
#
#
#
#
#                         미국에 있을 때 먹었던 시리얼인데, 이렇게 편하고 빠르게 로켓직구로 받을 수 있어서 감사해요.
#
# 배송
# 도착 예정일보다 4일 일찍 왔어요.
# (수요일 도착 예정이었으나, 토요일 도착.)
#
# 가격
# 환율 생각하면 미국에서 샀던 가격 그대로.
# 그런데 배송이 무료라는 것이 신기해요.
#
# 양
# 패밀리 사이즈라 혼자 먹으면 4주는 먹을 것 같아요.
# (전 이 시리얼을 매일 먹지는 않고, 오믈렛, 토스트, 죽, 오트밀 등을 번갈아 먹어서..)
#
# 특징
# 1. 이름 그대로 시나몬 팍팍 들어갔고,
# 2. 정말 크런치 해요.
# 우유에 말아놓고 5분 지났을 때도 크런치 해요.
# 3. 시나몬+설탕 조합 때문에 츄로스 맛을 느낄 수 있어요.
# 실제 한국 과자 중에 츄로스 맛과 약간 비슷해요.
#
# 츄로스 좋아하는데 그래도 개인적으로 이게 더 맛있어요.
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[5]').click()

# %%
#4p리뷰
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
review4 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in review4:
    print (re.text)
# Out:
#
#                         매우 위험한과자다...어땋게 이런과자를 만들수있나...야비하도다 한번뜯어서 맛보면 시토크로 가는 손을도저히 멈출수 없다
#
#
#
#
#                         이거 진짜 맛있어요. 우리나라에서는 먹을 수 없는 맛. 미국 시리얼 직구해서 먹으니 너무 좋아요. 유통기한도 거의 1년이네요 ㅎ
#
#
#
#
#                         오트밀 시리얼을 검색하다가 맛있을것 같아서 주문해보았어요.
# 개인적으로 시나몬향을 좋아하는데 은은한 시나몬향이 나고
# 바삭하면서 맛 괜찮네요.
# 근데 우유에 말면 바삭함이 금방 사라지긴 합니다.
# 기존에 먹던 시리얼들은 우유에 말아도 바삭함이 일정시간
# 유지가 되는데 그 점은 조금 아쉽네요.
# 요 제품 특히 아이들이 잘먹더군요.
# 생각보다 많이 달진 않아서 좋습니다.
#
#
#
#
#                         미국에서 먹던맛 너무 맛있어요~~ 버터녹여서 마시멜로녹여서 저거 넣고 시나몬토스트크런치 바나 스퀘어느낌으로 먹어도 너무너무 맛잇어요
#
#
#
#
#                         딱 1개만 먹어보면 알아요~
# 이건 납작한 츄러스입니다!!
# 지퍼백이 아니라서 맛보고 지퍼백에 담았어요.
# 시리얼보단 과자로 먹게 될것같아요

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[6]').click()

# %%
#리뷰5p
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
review5 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in review5:
    print (re.text)
# Out:
#
#                         유명하길래 시켜봤는데 생각보단 별로였음
# 하지만 입맛에 따라 다른것이기 때문에 한번쯤은 먹어봐도 좋을듯!
# 같이 먹은 사람중에 저빼곤 다 괜찮았다네요
#
#
#
#
#                         시중에 파는 과자 츄러스맛이랑 비슷한데 음 ~~ 생각보다는 달고 짠맛도 느껴졌어요 -
#
# 심심한 맛 좋아하는 저는 자주 먹지는 못 할거같고 당 떨어진다- 단거먹자 싶을때 찾을거같아요
#
# 근데 상자 뒷면 너무 깜찍하네요*-*
#
#
#
#
#                         시나몬향이 강해서 그냥 먹으면좋은데 우유에넣으면 그 맛이 확 사라져서 조금 아쉬웟어요
#
#
#
#
#                         이게 몇 번째 구입인지... 저희집 초딩은 제너럴밀스 씨리얼 아니면 안먹어요~ 저도 좋아합니당 :)
#
#
#
#
#                         진짜마싯네여ㅋㅋ식감도완전바삭바삭
# 맥주안주로도 굿임.. 와.. 시나몬향가득+설탕
# 엄청달아여  넘흐마싯음

# %%
#이거는 상세문구
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
inform1 = soup.find_all('table','prod-delivery-return-policy-table essential-info-table')

for re in inform1:
    print (re.text)
# Out:
# 식품의 유형
# 기타가공식품
# 생산자 및 소재지
# 알 수 없음(판매자 정보 미제공), 업데이트 예정
#
#
# 제조연월일, 유통기한 또는 품질유지기한
# 상세 내용 참조
# 포장단위별 용량(중량), 수량
# 340g, 1개
#
#
# 원재료명 및 함량
# 원재료명 : 컨텐츠 참조, 함량: 컨텐츠 참조
# 영양성분
# 컨텐츠 참조
#
#
# 유전자변형식품에 해당하는 경우의 표시
# 알 수 없음(판매자 정보 미제공)
# 표시광고사전심의필 유무 및 부작용 발생 가능성
# 알 수 없음(판매자 정보 미제공)
#
#
# 수입식품 문구
# 해당사항 없음
# 소비자상담관련 전화번호
# 쿠팡 고객센터 1577-7011

# %%
#상품 홍보 정보
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
ad1 = soup.find_all('div','subType-TEXT')

for re in ad1:
    print (re.text)
# Out:
#  General Mills 제네럴밀스 시나몬 토스트 크런치 시리얼  ✔ 바삭바삭한 식감의 통곡물 시리얼 ✔ 맛있는 시나몬 맛 ✔ 인공 색소 및 향료 불포함   바삭바삭한 식감의 통곡물 시리얼이에요. 영양분이 풍부하고 시나몬을 더해 더욱 맛있답니다. 바쁜 아침, 간편하게 먹기 좋아요.
#
#
# 브랜드 이야기  General Mills는 식품 업계를 선도하는 글로벌 브랜드로 Cheerios, Nature Valley 등 다양한 제품을 생산합니다. 영양분이 풍부한 식품을 제공하여 고객들이 더 나은 삶을 살 수 있도록 노력합니다.

# %%
review5
# Out:
# [<div class="sdp-review__article__list__review__content js_reviewArticleContent">
#
#                          유명하길래 시켜봤는데 생각보단 별로였음<br/>
#  하지만 입맛에 따라 다른것이기 때문에 한번쯤은 먹어봐도 좋을듯!<br/>
#  같이 먹은 사람중에 저빼곤 다 괜찮았다네요
#
#                  </div>,
#  <div class="sdp-review__article__list__review__content js_reviewArticleContent">
#
#                          시중에 파는 과자 츄러스맛이랑 비슷한데 음 ~~ 생각보다는 달고 짠맛도 느껴졌어요 - <br/>
#  <br/>
#  심심한 맛 좋아하는 저는 자주 먹지는 못 할거같고 당 떨어진다- 단거먹자 싶을때 찾을거같아요<br/>
#  <br/>
#  근데 상자 뒷면 너무 깜찍하네요*-*
#
#                  </div>,
#  <div class="sdp-review__article__list__review__content js_reviewArticleContent">
#
#                          시나몬향이 강해서 그냥 먹으면좋은데 우유에넣으면 그 맛이 확 사라져서 조금 아쉬웟어요
#
#                  </div>,
#  <div class="sdp-review__article__list__review__content js_reviewArticleContent">
#
#                          이게 몇 번째 구입인지... 저희집 초딩은 제너럴밀스 씨리얼 아니면 안먹어요~ 저도 좋아합니당 :)
#
#                  </div>,
# ...

# %%
driver = webdriver.Chrome('C:/Users/sungj/jspyth/chromedriver') #이거를 실행하면 빈창이뜨는데 빈창을 끄면 안돼!!

# %%
url2 ='https://www.coupang.com/vp/products/102062?itemId=182932&vendorItemId=3708269827&sourceType=CATEGORY&categoryId=195168&isAddedCart='
driver.get(url2)

# %%
html=driver.page_source #1p리뷰
soup = BeautifulSoup(html,'lxml')
#댓글가져오기
pro21 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro21:
    print (re.text)
# Out:
#
#                         예전부터 애용하던 제품이에요
#
# 요즘 한국 켈로그에서도 같은 제품이 나와서 몇 번 사먹었는데 맛이나 식감이 많이 달라서 실망이 컸어요 좀 더 진득거리고 향이 안좋았어요
#
# 직구로 받고 한 봉 먹어보니 그때그맛 그대로네요
# 오후에 당 떨어질 때 한 팩 먹으면 천국을 느낄 수 있어요
#
# 라이스 시리얼은 바삭바삭하고 마쉬멜로우는 쫄깃거려서
# 식감도 좋고 달달해서 간식으로 딱 좋아요
#
# 포만감은 그리 크지않으니 식사대용 시리얼 바 보다는
# 달달한 스낵으로 드시면 좋을 듯 해요
#
# 유통기한은 2021년 5월 까지,
# 13,000원에 구입했어요
#
#
#
#
#                         구입한  까닭이 있다면 〰〰✒
#
#  시리얼바를 애정하는 저는 가끔씩 눈에 띄는  아이들을
# 뜬금없이 업어오죠. 특히, 구입할 건 없고,  내일 당장
#  필요한 상품은 있고, 무배 19.800원을 채워야하니,
# 하는 수없이 굳이 필요치않는 품목중에서도 걔중에서
#  가장 필요한 것을 찾아 삼만리길을 떠나죠.
# 그 걔중의 하나가 제게는 시리얼바예요 ㅠㅠ
#
# 이번에도 그런경우예요. 1박스만 있어도 저혼자만
#  먹는거라 많이 필요치 않지만,
# 1박스는 로켓배송으로는 판매하지않아 하는 수 없이
# 두 박스를 구매해요. 로켓배송 품목에서는 기본 판매량이
#  2박스니깐요.
# 그런데, 갈수록 로켓배송 품목이 줄어든다는 걸 느껴져요.
#
#  이런 느낌이야 오래된 느낌이지만,  또 절절하게 느낀 주문건수가 오늘 있어서 그냥 구시렁구시렁 댑니다.
#
# °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°
# 쿠팡애가족님, 안녕하세요  :)
# 리뷰어 Micha는 펼쳐진 책처럼 보시는 그대로
# 지극히 개인적인 상품평으로~ 저의 직접경험에 의한
# 작성입니다.
# 동영상과 사진은 함께 보시면 도움이 더 되실거예요 :D
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[3]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro22 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro22:
    print (re.text)
# Out:
#
#                         제가 이걸 중학교 2학년 때 코스트코에서 사온 친구 덕분에 처음 먹어보게 됐는데 그때 넘넘 맛있어서 ㅠㅠㅠ 이름 물어보려다 금방 까먹고 한동안 잊고 살았다가 10년이 지난 지금 ㅠㅠㅠ 우연히 그 과자가 생각나서 검색하다가 찾게 되어가지고 ㅠㅠㅠ 때마침 쿠팡에 팔길래 와 진짜 ㅠㅠㅠㅠㅠㅠ 직장언니한테 엄청 호들갑 떨었어요 ㅠㅠㅠㅠㅠㅠ 아직까지 파는구나 싶고ㅠㅠㅠㅠㅠㅠ 그 맛을 다시 맛보게 될 걸 생각하니까 아주ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 사족은 여기까지 하고 택배는 제가 받질 않았지만 기사님이 친절하게 문자까지 남겨주시구ㅠㅠㅠㅠㅠ 에어캡도 빽빽 넣어주셔가지고 과자가 망가지지도 않고 진짜 ㅠㅠㅠㅠ맛은 여전히 맛있고ㅠㅠㅠㅠㅠㅠ 요번에 한번 시킬때 60개 정도 시킨 거 같은데 가족들이랑 먹고 직장 언니들이랑 먹고 해여겠어요 아우ㅠㅠㅠ 넘나 조와요 ㅎㅎㅎ팔아주셔서 감사합니다 ~~~~
#
#
#
#
#                         40갸 부족해요 60개 사세요 제발루~~~~~
#
#
#
#
#                         배송음 하루만에 빠른 배송 받았어요~
# 큰 쿠팡박스에 와서 깜놀
# 한박스 큰거였네요
# 맛은 생각하고 있는 그밋 그대로에요~ 달달하고 겉은 살짝 바삭한듯 한데 씹으면 약간 진득한 느낌이에요~ 다달한거땡길때는 하나 다 먹어도 되는데 아닐때는 한개 먹어도 엄청 달아요!
# 그래도 가방에 하나씩 챙겨 가지고 다니면서 먹기에 딱 좋네요!!
#
#
#
#
#                         맛있다고 추천해서 샀는데
# 처음 먹고 너무 단데?이거 잘못산거아냐?? 싶었는데
# 우유랑 먹으니 딱이네요~ 4살애기도 우유랑 간식으로 종종 주고있어요 너무 잘먹네요
# 한개두개 먹다보니 이젠 계속 손이가요ㅠ ㅠ
# 당떨어질때 먹으면 딱좋아요^^ 전 추가구매해요~
# 참고로 켈로그 라이스바랑 같은맛일줄 알았는데 달라요
# 이게 훨씬 부드럽게 달아요~
#
#
#
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[4]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro23 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro23:
    print (re.text)
# Out:
#
#                         사실 많이 달아요. 그치만 너무 맛있습니다
# 육아에 지친 엄마들 피로도 풀어주고
# 아빠 출근길에 하나 먹고 힘내고
# 배고플때나 우울할때나 과자먹고싶을때
# 한개만 먹어도 달아서 충분해요.
# 하지만 두개먹을때도 있어요^^;
#
# 가격이 저렴해서 제일좋고
# 두번째는 양이 많아서 뭔가 채워진듯한
# 풍성함이 있어요.
#
# 기분도 좋아지고 맛나요
#
#
#
#
#                         이거 맛있어 미치겠다는 상품평 쓰신분들...
# 흠..하긴 사람 입맛이 뭐..천차만별이라지만..
# 난 이거 왜 돈주고 사먹는지 모르겠음요..
# 뭐 하나 딱 부러지게 내세울게 없는
# 미지끈하고 진득하고 달고 찜찜..
# 아..모르겠다..암튼 우리애 간식으로 학원 갈때마다
# 챙겨주려고 주문한건데 애가 하나도 제대로
# 못먹네요..
# 우리 조카들도 입에 한번 데고는 안먹고
# 내입만 안맞는게 아닌듯.
# 돈 버렸네여.
#
#
#
#
#                         배고플때 간단하게 먹을 영양 곡물바를 찾다가 주문
# 바삭한 강정을 달달한 연유에 담궜다 뺀듯 살찌는 맛
# 먹다보면 심장에 무리올 정도의 지독한 달콤함
#
#
#
#
#                         화이트 초코 아닌 연유 범벅 미국식 쌀튀밥 뭉치
# 쫀득하고 부드러워서 아이들이 좋아해요. 아침에 우유한잔에 간단히 요기거리로 구매
#
#
#
#
#                         굉장히 달아여
#
# 추억의 과자 중에 오란다 말고 더 작은 알갱이로 튀겨서 물엿 같은 거에 버무려서 강정 만들어 놓은 거 있잖아여~
# 이거는 물엿 대신 머쉬멜로우 같은 걸로 버무린 듯한 맛이에여
# 엄청 달아가지고 먹으면서도 "와, 심하네. 달다. 달다. 윽, 달다!!"
# 이러는데 계속 들어감 ㅋㅋㅋㅋㅋㅋ
# 우유나 커피같은 거랑 같이 먹으면 더 맛있을 거 같아여

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[5]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro24 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro24:
    print (re.text)
# Out:
#
#                         예전에 먹었다가 이름을 까먹어서 비슷한제품들 사먹었었는데 다 꽝이였거든요ㅠ
# 근데 찾았어요!
# 이거에요!
# 진짜 이 식감과 맛이 이 제품만에 맛이 있어요
# 달긴 많이 단편이에요
# 크기도크고 부드럽고 쫀득?하다고 해야하나 하...
# 단거 좋아하시면 한번 드셔보시는거 추천합니당♡
#
#
#
#
#                         호불호가 갈리는 맛. 미국 과자라 매우 달다. ㅋㅋ 그치만 저는 이 마시멜로우 맛을 좋아하기에 구입했고 학생들에게 나누어주려고 샀는데 이 맛에 한반 빠진애들은 헤어나오지 못합니다. 이 맛을 싫어하는 애들은 두 번 다시 과자 달란 소리 안해서 편하고요~ ㅋㅋ 여러모로 쓸모있는 과자입니다 ㅎㅎ
#
#
#
#
#                         작은사이즈 사다가.. 하루이틀이면 다 먹어없어지고.
# 아이들은 자꾸찾고..그래서 요걸로 샀어요.
# 엄청 크네요ㅋㅋㅋㅋ
# 느낌으로 54개 넘는듯해요ㅋㅋ 빈틈없이 상자에 꽉꽉.
# 제 입에는 너무 달아서;; 1개이상 못먹겟는데.
# 아이들은 잘먹네요.
# 근데 생각보다 유통기한이 짧은듯요.
# 오늘 받았는데 2017.5.17 까지네요
#
#
#
#
#                         코스트코에서 가면 꼭사와야하는 리스트에 포함대있는것
#
# 그래서 주문했다 나두 맛좀보려고ㅎㅎ
#
# 갠적인생각으로 조금 단맛이 강하다
#
# 맛이 마시멜로를 녹여놓은 맛이라고 적혀있다
#
# 많이먹음 질리는맛
#
# 하지만 일반 곡물바와는 달리 엄청난부드러움과 달달함
#
# 이런맛을 좋아하는 사람에겐 추천!
#
#
#
#
#                         정말 보들보들 쫄깃쫄깃 아침엔 퍽퍽이 보단 요게 훨 좋아요

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[6]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro25 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro25:
    print (re.text)
# Out:
#
#                         매우달고 촉촉해요.
# 전 딱딱하지 않아서 넘 맘에 들었어요
# 하지만 한꺼번에 많이 먹기는 매우 부담스럽고 매우 달아요
# 단맛이당길때나 스트레스 받을때 한두개정도 먹기 딱일듯 합니다.사이즈는 기본 바보다 약간 작은사이즈예요
#
#
#
#
#                         가격도괜찮고 식사대용으로 먹기위해 구매하였습니다 ㅇㅂㅇ맛있겟잘먹겠습니다~
#
#
#
#
#                         초등학생때부터 간식으로 먹었는데...... 지금 10여년정도 된거같아요. 몇박스 시켜놓으면 특유의 향과 단맛에 얼마못먹고선 좀 물려서 주위사람들 다 나눠주고 하지만, 계속해서 꾸준히 먹게되는 마성의 맛입니당. 아마도 앞으로 계속 출시된다면 평생을 먹지않을까 싶네요 ㅋㅋ
#
#
#
#
#                         국내에서 파는 호랑이 그려진 켈로그 라이스 크리스피바 오리지널이 더 맛있네요
#
#
#
#
#                         전부터 좋아하던거 코스트코나 직구로 한박스 크게 사서 먹곤했는데
# 여기서 보고 바로 구매합니다
# 사람 취향에 따라 다르지만
# 한번만 먹은사람은 없을꺼같은 중독적인맛 식감
# 생각보다 칼로리도 낮아서 놀란 그 과자
# 못먹으신분들은 빨리 먹어보길바랍니다

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro2in = soup.find_all('div','subType-TEXT')

for re in pro2in:
    print (re.text)
# Out:
#  Kellogg's 켈로그 라이스 크리스피 트리트 오리지널 바  ✔ 쌀로 만든 달콤한 간식 ✔ 쫄깃한 마시멜로 ✔ 트랜스 지방 불포함 ✔ 액상 과당 불포함    오븐에 구운 푹신한 쌀과 달콤한 마시멜로로 만든 완벽한 간식입니다. 지친 하루에 기운을 줄 수 있는 달콤한 간식을 사무실, 학교 등 어디에서나 즐겨보세요!
#
#
# 브랜드 이야기   1906년 설립된 Kellogg는 맛있는 고품질의 시리얼을 제공합니다. 100년 이상의 역사를 가진 Kellogg는 혁신적인 프리미엄 시리얼을 지속적으로 연구하고 생산하여 업계를 선도하고 있습니다.

# %%
driver.find_element_by_xpath('//*[@id="itemBrief"]/div/p[2]/a').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro2el = soup.find_all('table','prod-delivery-return-policy-table essential-info-table')

for re in pro2el:
    print (re.text)
# Out:
# 식품의 유형
# 기타가공식품
# 생산자 및 소재지
# Kellog's, 업데이트 예정
#
#
# 제조연월일, 유통기한 또는 품질유지기한
# 상세 내용 참조
# 포장단위별 용량(중량), 수량
# 22g, 40개입
#
#
# 원재료명 및 함량
# 원재료명 : 컨텐츠 참조, 함량: 컨텐츠 참조
# 영양성분
# 컨텐츠 참조
#
#
# 유전자변형식품에 해당하는 경우의 표시
# 알 수 없음(판매자 정보 미제공)
# 표시광고사전심의필 유무 및 부작용 발생 가능성
# 알 수 없음(판매자 정보 미제공)
#
#
# 수입식품 문구
# 해당사항 없음
# 소비자상담관련 전화번호
# 쿠팡 고객센터 1577-7011

# %%
driver = webdriver.Chrome('C:/Users/sungj/jspyth/chromedriver') #이거를 실행하면 빈창이뜨는데 빈창을 끄면 안돼!!

# %%
url3='https://www.coupang.com/vp/products/1130121?itemId=22898943&vendorItemId=3286216286&sourceType=CATEGORY&categoryId=493405&isAddedCart='
driver.get(url3)

# %%
html=driver.page_source #1p리뷰
soup = BeautifulSoup(html,'lxml')
#댓글가져오기
pro31 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro31:
    print (re.text)
# Out:
#
#                         ✔️쿠엔크는 솔직히 그저 그렇네요 ㅋ
# 제가 먹어본 머슬팜 프로틴바 종류는
#
# 1. 초코케이크
# 2. 피넛초코
# 3. 쿠엔크
#
# 세가지이고, 맛 별 순위입니다.
#
# ✔️초코케이크 맛은 풍부하고 부드러운
# 버터초코 필링 느낌이 강합니다
# 식감도 쫀득하니, 프로틴 향도 첫 한 입 이후로는
# 아무 생각없이 넋을 놓고 먹게됩니다
# * 역대 프로틴바 중에서 제일 맛있어요 설탕의 힘!?
#
# ✔️피넛초코는
# 자유시간 맛이에요 ㅇㅅㅇ
# 많이 달달한데 맛있습니다
# 먹을만해요
#
# ✔️쿠엔크는
# 프로틴향이 입 안에 좀 남아있어요
# 그리고 쿠엔크? 오래오 특유의 발향이 없네요 ㅠㅠ
# 그저 내용물에 쿠키 조각들이 있어,
# 식감이 좀 크런키햐서 재미지다는 느낌뿐?
#
#
# 머슬팜 프로틴바는
# ✔️100% 슈가프리가 아니니
# 성분 잘 확인하시고 선택하세요
# 식이탄수를 제외하고도
# 일반적인
# 단당류와 이당 조합으로 첨가되어 있습니다
# 대략적으로
# *설탕 5g
# *탄수 7g
# *당 함량 총 12g
#
#
# 키토제닉이나 저탄수등의
# 당질 제한식에는 맞지 않는 간식이에요
#
# 100% 슈가프리는
# 어쩔 수 없이 퀘스트바나 카브라이트,
# 이런 감미료로 단맛을 표현한 쪽으로
# 선택하셔야 할 듯요
#
# 저번 상품평에도 남겼는데
# ✔️머슬팜은 운동하면서 드실분 위주로 초이스!!
# ✔️벌크업 위주인 분들만 ㅇㅇ..
#
# 절식 다이어트용으로는 .. 글쎄요??
# “그래도 이게 일반 초코바 보다는 낫잖아?”
# 하면서 노냥 맨날 드실 것 같아서요
# 제가 그러거든요 ㅎㅅㅎ;;
# 1일 1바 중 ..젠장...
#
# 구매는 쿠팡와우 멤버?
# 뭐시기 멤버 해택으로
# 골든박스 이벤트일 때
# 박스당 18,000원 선에 구입했어요
# 원래 가격은 23,000원대 인걸로 기억 ㅇㅇ
#
#
#
#
#                         이름그대로 푸석푸석 크런키  합니다..
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[3]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro32 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro32:
    print (re.text)
# Out:
#
#                         뭐랄까
# 처음 한입은
# 으.. 역시
# 프로틴 냄새!! 인데
# 두 세입 먹다보면
# 나쁘지 않아! 입니다
# 반 정도 먹었을 땐,
# 좋은데? 이정도면 먹을만한데? 확정 ㅇㅇ
# ✔️맛은 먹을수록 괜찮습니다
# ✔️초콜렛 퍼지 느낌이 강해요
# ✔️쫀득거린단 느낌 보다는
# ✔️부드러운 식감에 약간의 쫀득함이 가미됨 느낌이에요
# ✔️절대 나쁘지 않은 맛
#
# 그간 직구에서 프로틴바는 많이 접했는데
# 판매량 높은 퀘스트바보다는 맛 면에서 우월합니다
# 하지만,, 성분이 뭐랄까
# ✔️운동 안 하는 절식 다이어트 간식용으로는
# ✔️조금 투머치인 것 같아요.
# 물론 시판되는 일반 간식류보다는
# 낫겠지만, 특히 키토식에는 부적합 한 듯해요ㅎㅎ
# 탄수8%
# (*식이섬유 비율48% , 나머지는 설탕과 일반 탄수=당임)
# 지방11%
# 단백질 40% 비율로
# 비율 적절하게
# 잘 맞춰진 한끼대용 에너지바 느낌이에요
#  *설탕이 아예 없었다면 좋았겠지만
# 당알콜로는 맛내기에 한계가 있겠죠??
# 감미료 부작용은 없을 것 같네요
# (슈가프리
# 제품 원하시는 분은 이 제품은 좀 아니에여~)
# 운동하면서 드실 분들에게는 최상일 듯 해요^^
#
#
#
#
#                         받자마자 먹어봤는데
# 한개당 양도 적당히 배부르고
# 맛은 프로틴 초코맛이 강한데 식감은 쫀득쫀들한 것이 시중의  핫브레이크 같은데 맛은 핫브레이크가 더 맛나요
# 엄청 중독되는 맛은 아니라서 오히려 다행이 것 같아요
# 조절 가능할것같아요 ㅋㅋㅋㅋㅋ 운동후에 먹으려고 주문했습니다 맛있게 잘먹을게요 ㅎㅎ
#
#
#
#
#                         우선 저는 20년 3 월 현재 다이어트 중인 39 여성 입니다
#
# 이 프로틴 바 저에겐 그렇게 달지 않아요
# 저는
# 케이크 마카롱같은 디저트류는 정말 입에 물지 않는
# 바게트나 시큼한 호밀빵 등을 더 좋아하는 맹맹입맛입니다
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[4]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro33 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro33:
    print (re.text)
# Out:
#
#                         맛은 그냥 딱 초코바 맛입니다
# 프로틴 맛 거의 나지 않아요
# 쫀득한 브라우니 같은 느낌?
# 다이어트 아니라도 그냥 맛으로 먹을 수 있을 것 같아요
# 다만 칼로리는 낮은 편은 아니라서
# 주의해야할듯
# 해외직구 사이트에서 32000원 주고 샀었는데
# 훨씬 싸게 주고 샀네요
#
#
#
#
#                         모든 프로틴바는 얼려서먹는편임
# 허벌라이프 초코피넛,바닐라
# 신타6 솔티드토피,초코크런치
# 퀘스트 스모어
# 이거 컴뱃 초코피넛 차례로먹어봄
#
# 허벌라이프는 좀꾸덕해서 얼렸다먹음 이가안들어가는데
# 작아서 뭔가되게소중해ㅡ ㅡㅋ여자손가락2개만함ㅋ아껴먹게되서 괜히마싯음ㅋㅋ근데비쌈 가성비꽝
# 나는 초코피넛이 맛있고 신랑은바닐라가 맛있다함
#
# 신타6은 크런키하고 사이즈도 대따크고 맛있음
# 근데 평이너무너무좋아서 맛을 기대했는데 사실 그정돈아니고 프로틴바치고는 프로틴바같지않은 식감과 단백질맛이안느껴진다는 장점.많이달고 커서 한번엔 못먹음 반반 나눠서먹었었음.
# 나는 솔티드토피가맛있고 신랑은 초코크런치가맛있다함
#
# 퀘스트바 스모어인기많길래 스모어한종류만 먹어봤는데 일단 내입엔 디기 별로. 엄청꾸덕해서 얘도 얼려먹으니 이가 안드가네ㅋㅋ 조금녹여서똑똑끊어먹으니 계피향머니 ㅡ ㅅ ㅡ
# 난계피향시러 그냥 초코맛아니었니?암튼 야도달아 거기다꾸덕하니 입이환장하겠다야 아암튼실타 11개남았다ㅡㅡ
# 난 그래도 꾸덕한건 맘에드네 그랬는데 신랑은 아예맛이없다함
#
# 퀘스트살때 컴뱃도구매
#
# 퀘스트안땡겨서 컴뱃먹었는데 힛?어라?겉은바삭 속은꾸덕이ㅋㅋ올~~맛있음ㅋㅋㅋ
# 물론얘도얼렸으니 내껀 겉은바삭 속은딱딱ㅋㅋ근데 잘끊어져 똑똑.
# 일단 초코가맛있는초코맛있고 딴거에비해 안달아서좋네
# 앞으로 프로틴바이거사야겠다.
# 대신 방금 신나게 먹고나니 입이텃텃함ㅋㅋㅋ뭐우야겠노
# 다 장단점이있는법 배부르게 물마이묵지뭐ㅋㅋ 근데물먹어도 이텁텁함은안가신다 혀가 텁텁함에 코딩됐으ㅋㅋ
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[5]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro34 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro34:
    print (re.text)
# Out:
#
#                         또 구입했어요.
# 사실 처음에 먹었을 땐 그 단백질 불내증인가?
# 유당 불내증 뭐 비슷한 거 때문에 속에서 계속 이상한 소리 나고 방구가 계속 나왔는데
#
# 유당불내증도 조금씩 계속 먹으면 내성생긴다길래
# 하루에 3분의 1씩 먹으면서 조금씩 양을 늘렸거든요?
# 그래서 그런지 지금은 한 개를 먹어도 딱히 속이 불편하지 않아요.
#
# 다이어트 하면서 초콜릿 안 먹기 정말 힘든데
# 이건 초콜릿을 완전히 대체할 수 있는 제품이라 너무 좋습니다.
#
#
#
#
#                         겨울대비 살도 찌우고 몸에 열도 내고 할려고 초콜렛을 찾다가 끌려서 구매 했습니다. 한국제품은 가성비가 꽝이라 수입으로 골랐어요.
#
# 주말포함 4일정도 걸려서 도착 했어요. 기쁜마음으로 뜯었는데 기대 했던거보다 작더라구요. 완전 손바닥만한줄 알았는데 사진에서 보이는 크기정도 ㅠ
#
# 그래도 다른초코바에 비하면 엄청 커서 두개 먹기엔 좀 부담스러워요
#
# 조금 딱딱한편이에요. 냉동실에 넣었다가 오늘 아침에 다시
# 꺼내놨어요. 실온에서도 좀 딱딱해요.
#
# 흔한초콜렛 맛은 아니에요 말로 설명하기 힘든 약간 독특한 맛이 납니다.
#
# 대체로 만족스러운데 가격에 비하면 그닥 메리트는 없는거 같아요.
#
# 어차피 금방 다 먹을거라서 유통기한은 안봤어요
#
# 가격이 비싸 재구매 의사는 없지만 맛은 있어요
#
#  쿠팡체험단 이벤트로 상품을 무료로 제공 받아 작성한 구매 후기입니다.
#
#
#
#
#                         정말 존맛
# 초콜릿 케이크만 먹다가 픔절되서 이거 샀는데
# 꼬리꼬리한 땅콩버터맛 이것도 충분히 달아옹
#
#
#
#
#                         다이어트 기간이라 프로틴바 간편하고 먹기 좋아서
# 요즘 이것저것 시키는데...
# 이거 일단 쿠키앤크림맛이 아니라 딸기우유맛이에요
# ...

# %%
driver.find_element_by_xpath('//*[@id="btfTab"]/ul[2]/li[2]/div/div[5]/section[4]/div[3]/button[6]').click()

# %%
html=driver.page_source
soup = BeautifulSoup(html,'lxml')
pro35 = soup.find_all('div','sdp-review__article__list__review__content js_reviewArticleContent')

for re in pro35:
    print (re.text)
# Out:
#
#                         스니커즈 같은 초코바가 생각나면 먹기 좋을 것 같아요 달달하고 입안에서 잘 들러붙는 편이 아니라서 먹기 편했어요
#
#
#
#
#                         프로틴바 처음 먹어보는데.. 와 그냥 초코퍼지바 맛이예요. 앞으로도 진짜 계속 먹을 것 같아요. 다이어트할때 저녁밥 대용으로 먹으러고 샀는데 아주 그냥 기가 막힙니다!!!!!
#
#
#
#
#                         역시 머슬팜, 믿고 먹어도 됩니다. 육겹바보단 꾸덕한데 역하지는 않아서 자주 챙겨먹을듯합니다.
#
#
#
#
#                         초콜릿 케이크랑 쿠키앤크림 두가지 구매했습니다
# 그런데 초콜릿 케이크의 밀봉씰만 벗겨져 있어서 뭔가 했더니 안에 갯수가 하나 모자라네요..
# 유통과정에서 누가 빼먹은 건지 뭔지ㅋㅋ
# 이런 경우는 처음이라 좀 황당합니다
# 이거 하나 불쾌했던 것 빼곤 프로틴바 자체는 맛있어요
#
#
#
#
#                         쿠키앤크림맛이 그닥 나지않아요 ㅋㅋㅋ 이건 사실 무슨 맛인지 모르겟음...ㅋㅋ 쫀득한 느낌이 좋아서 걍 먹어요 ㅋㅋ
#
# 초콜릿케이크만한 맛이없네요 컴뱃은 ㅋ
