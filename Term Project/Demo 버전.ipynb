# %%
# 패키지 설치

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import pandas as pd
import os

# %%
snack_1 = pd.read_csv('retry04.txt', sep = "\t", engine='python', encoding = "UTF-8")
snack_1.head()
# Out:
#                                              ,review
# 0                                 0,"쿠키에 넣으려고 구매했어요.
# 1  도리토스, 치토스, 썬칩, 프렛즐을 따로 따로 구매하기가 싫어서 이 미니팩을 골랐는데요.
# 2                   크게 부수면 1C도 채 되지 않는 미니미니한 사이즈입니다.
# 3  달콤하고 짭쪼롬한 단짠단짠의 맛에 간간이 매운 맛이 훅 올라와 재미있는 쿠키가 만들...
# 4                         먼치스 스낵 믹스를 더해 만든 쿠키 최고예요."

# %%
snack_2 = pd.read_csv('retry06.txt', sep = "\t", engine='python', encoding = "UTF-8")
snack_2.head()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2694         try:
# -> 2695             return next(self.data)
#    2696         except csv.Error as e:
#
# Error: '	' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-28-ba60b9f4e234> in <module>()
# ----> 1 snack_2 = pd.read_csv('retry06.txt', sep = "\t", engine='python', encoding = "UTF-8")
#       2 snack_2.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2237     def read(self, rows=None):
#    2238         try:
# -> 2239             content = self._get_lines(rows)
#    2240         except StopIteration:
#    2241             if self._first_chunk:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _get_lines(self, rows)
#    2969                         while True:
#    2970                             new_row = self._next_iter_line(
# -> 2971                                 row_num=self.pos + rows + 1)
#    2972                             rows += 1
#    2973
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2715                     msg += '. ' + reason
#    2716
# -> 2717                 self._alert_malformed(msg, row_num)
#    2718             return None
#    2719
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _alert_malformed(self, msg, row_num)
#    2674
#    2675         if self.error_bad_lines:
# -> 2676             raise ParserError(msg)
#    2677         elif self.warn_bad_lines:
#    2678             base = 'Skipping line {row_num}: '.format(row_num=row_num)
#
# ParserError: '	' expected after '"'

# %%
data2 = pd.read_csv('retry02.txt', sep = "\t", engine='python', encoding = "UTF-8")
data2.drop_duplicates()
# Out:
#                                                ,review
# 0                            0,"☆하리보 스타믹스 젤리 1kg 주문하기☆
# 1    요즘엔 간식도 낱개포장된것만 자꾸 찾아 구매하게 되네요! 지난번에 하리보젤리 구매해...
# 2                                         ☆하루만에 만났어요!☆
# 3    하루만이라고 하기에도 더 짧은 시간이에요. 저녁에 주문했는데 새벽 2시에 도착했네요...
# 4    동그란 투명 통은 똑같구요. 앗! 제가 착각한게 있네요. 지난번에 구매한 하리보가 ...
# 5                               ☆하리보 스타믹스 젤리 한봉지 열어보기☆
# 6    사실 상자 열기전부터 새콤달콤한 향에 빨리 한봉지 먹고싶더라구요. 진짜 향이 너무 ...
# 7    40봉지 금방 다 먹을 것 같아요ㅋㅋㅋ 옆에서 아빠도 한봉지 뜯고계신데요? 으악~~...
# 8                    1,"@ 아이 어른 함께먹을 주전부리 간식으로 주문했어요~@
# 9          하리보 골든 곰젤리만 먹다가 이번에 스타믹스로 바꿔서 주문해봤는데 맛있네요~~
# 10                       한봉지에 들어있는 다양한 젤리들이 여러가지맛을 내니까
# 11                                     맛도있고 눈도 즐겁네요~^^
# 12     모양도 귀여워요~~아이도 맛있는지 자꾸 달라해서 한번씩은 통째로 숨겨놓기도 합니다 ㅎ
# 13                      제느낌상 한봉지당 들어있는 그람수가 동일하진 않는듯해요
# 14        큰오차는 아니겠지만 젤리가 조금꽉찬 봉지도있고 좀 덜들어간듯한 봉지도 있어요~~
# 15           젤리 모양 역시 골고루 든것도 있지만 곰만 너무 많이 들어간것도 보이네요~
# 16                         복불복~^^ 저는 그중 계란후라이가 젤 맛있네요~
# 17                      아이들 간식으로 좋습니다 양도 많으니 오래먹겠어요~♡"
# 18                       2,"딸 아이가 친구들에게 간식 나눠 주고 싶다고하여
# 19                               곧 할로윈도 다가오고 해서 주문했어요.
# 20                              로켓 박스에 포장되어 훼손없이 왔습니다.
# 21                           40개입인데 세어보니 46개가 들어있어요~!!
# 22                        양이 많고, 아이들이 까먹더니 맛있다고 잘 먹네요.
# 23              젤리중에 하트 뒷면 하얀부분과 계란후라이 흰자 부분은 마시멜로우예요ㅋ
# 24                                            전 맛있었어요ㅋ
# 25                          반지모양 젤리도 있네요~ 딸 아이가 좋아합니다.
# 26   마스크 개별포장 하려고 사둔 opp봉투에(12*18) 다*소 가서 산 할로윈 스티커...
# 27                                         잘 선물 할게요^^"
# 28   3,"커다란박스에 배송되서 깜짝 놀랐고 열어봤더니 또 어마무시한 크기의 하리보원통에...
# 29                                     울 강아지가 쿠팡 상자만열면
# ..                                                 ...
# 729                                           크도 별로 예여
# 730                                     칼로리가 엄청나서요 ㅎㅎ"
# 731                                 264,"엄마는외계인의 초콜릿과자
# 732                           손이한번 가면 멈추질 않는 마성의 과자...
# 733                                   하 왜삿을까요... 내살...
# 734                                        너무 마싯써!!!!"
# 735  265,"맛있어요. 애들이 우유에 말아먹는데, 두시간만에 온가족이 반이상 먹어버렸어...
# 736  266,몰티져스 너무너무 먹고싶어서 찾아보다가 대용량에 이렇게 착한 가격은 없을 것...
# 737                                   267,"생각보다 통이 작네요
# 738                                    아이들이 사달라고 이야기해서
# 739                                 주문했는데..뚜껑 열어보니 초콜렛
# 740                                            향 가득하네요
# 741                                     맛있게 잘 먹으면 되는거니
# 742                                     우유에 타먹으면 맛있다해서
# 743                                         그렇게 주려구요~~
# 744                                         잘 먹겠습니다.."
# 745  268,"맛이 궁금해서 구매했는데, 한개 먹고, 두개 먹고, 세개,네개... 나도 ...
# 746                              정신을 차리고 바로 뚜껑을 덮었지요."
# 747                         269,"바삭한 내부, 달콤한 초콜릿 코팅 굿굿
# 748                                      처음 먹는데 반해버렸음"
# 749                                    270,"녹지않고 잘 왔어요
# 750                                   아이가 너무 좋아해서 시켰는데
# 751                                  3일만에 한통을 다 먹어버렸어요
# 752                                       그래서 또 시키러...
# 753                                    저도 몰티저스에빠져버렸네요"
# 754                            271,"저희 아들이 자꾸 사달라고 졸라서
# 755                                주문햇습니다. 너무 맛있어요*^*"
# 756                                               272,
# 757  273,"구매하고 하루 뒤에 가격이 2천원이나 떨어졌더라구요,, 상품도 생각보다 너...
# 758  274,==========================================...
#
# [742 rows x 1 columns]
